# %% [markdown]
# <a href="https://colab.research.google.com/github/seyonechithrananda/dorian-grey-gpt2/blob/master/doriangrey_entirebook_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 1.x
# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
#      |████████████████████████████████| 645kB 7.7MB/s
#   Building wheel for gpt-2-simple (setup.py) ... done
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## GPU
#
# Colaboratory uses either a Nvidia T4 GPU or an Nvidia K80 GPU. The T4 is slightly faster than the old K80 for training GPT-2, and has more memory allowing you to train the larger GPT-2 models and generate more text.
#
# You can verify which GPU is active by running the cell below.

# %%
# !nvidia-smi
# Out:
# Mon Nov 18 03:08:30 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 430.50       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P8    35W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Downloading GPT-2
#
# If you're retraining a model on new text, you need to download the GPT-2 model first.
#
# There are three released sizes of GPT-2:
#
# * `124M` (default): the "small" model, 500MB on disk.
# * `355M`: the "medium" model, 1.5GB on disk.
# * `774M`: the "large" model, cannot currently be finetuned with Colaboratory but can be used to generate text from the pretrained model (see later in Notebook)
# * `1558M`: the "extra large", true model. Will not work if a K80 GPU is attached to the notebook. (like `774M`, it cannot be finetuned).
#
# Larger models have more knowledge, but take longer to finetune and longer to generate text. You can specify which base model to use by changing `model_name` in the cells below.
#
# The next cell downloads it from Google Cloud Storage and saves it in the Colaboratory VM at `/models/<model_name>`.
#
# This model isn't permanently saved in the Colaboratory VM; you'll have to redownload it if you want to retrain it at a later time.

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 167Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 96.2Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 439Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:05, 84.2Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 468Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 156Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 156Mit/s]

# %% [markdown]
# ## Mounting Google Drive
#
# The best way to get input text to-be-trained into the Colaboratory VM, and to get the trained model *out* of Colaboratory, is to route it through Google Drive *first*.
#
# Running this cell (which will only work in Colaboratory) will mount your personal Google Drive in the VM, which later cells can use to get data in/out. (it will ask for an auth code; that auth is not saved anywhere)

# %%
gpt2.mount_gdrive()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
file_name = "doriangrayentirebook.txt"

# %% [markdown]
# If your text file is larger than 10MB, it is recommended to upload that file to Google Drive first, then copy that file from Google Drive to the Colaboratory VM.

# %%
gpt2.copy_file_from_gdrive(file_name)

# %% [markdown]
# ## Finetune GPT-2
#
# The next cell will start the actual finetuning of GPT-2. It creates a persistent TensorFlow session which stores the training config, then runs the training for the specified number of `steps`. (to have the finetuning run indefinitely, set `steps = -1`)
#
# The model checkpoints will be saved in `/checkpoint/run1` by default. The checkpoints are saved every 500 steps (can be changed) and when the cell is stopped.
#
# The training might time out after 4ish hours; make sure you end training and save the results so you don't lose them!
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.
#
# Other optional-but-helpful parameters for `gpt2.finetune`:
#
#
# *  **`restore_from`**: Set to `fresh` to start training from the base GPT-2, or set to `latest` to restart training from an existing checkpoint.
# * **`sample_every`**: Number of steps to print example output
# * **`print_every`**: Number of steps to print training progress.
# * **`learning_rate`**:  Learning rate for the training. (default `1e-4`, can lower to `1e-5` if you have <1MB input data)
# *  **`run_name`**: subfolder within `checkpoint` to save the model. This is useful if you want to work with multiple models (will also need to specify  `run_name` when loading the model)
# * **`overwrite`**: Set to `True` if you want to continue finetuning an existing model (w/ `restore_from='latest'`) without creating duplicate copies.

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='124M',
              steps=1000,
              restore_from='fresh',
              run_name='entirebook',
              print_every=10,
              sample_every=200,
              save_every=500,
              learning_rate = 0.0001
              )
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  1.23it/s]
# dataset has 124640 tokens
# Training...
# [10 | 19.29] loss=3.15 avg=3.15
# [20 | 31.61] loss=2.88 avg=3.01
# [30 | 43.94] loss=2.73 avg=2.92
# [40 | 56.24] loss=2.62 avg=2.84
# [50 | 68.57] loss=2.57 avg=2.79
# [60 | 80.91] loss=2.83 avg=2.79
# [70 | 93.23] loss=2.70 avg=2.78
# [80 | 105.55] loss=2.45 avg=2.74
# [90 | 117.88] loss=2.13 avg=2.67
# [100 | 130.19] loss=2.27 avg=2.63
# [110 | 142.49] loss=2.22 avg=2.59
# [120 | 154.79] loss=2.05 avg=2.54
# [130 | 167.11] loss=2.09 avg=2.50
# [140 | 179.41] loss=1.90 avg=2.46
# [150 | 191.71] loss=1.77 avg=2.41
# [160 | 203.99] loss=1.67 avg=2.36
# [170 | 216.28] loss=1.68 avg=2.32
# [180 | 228.59] loss=1.45 avg=2.26
# [190 | 240.91] loss=1.44 avg=2.22
# [200 | 253.24] loss=1.44 avg=2.17
# ======== SAMPLE 1 ========
#  talk, and I thought ye had discovered the secret of the beautiful. I felt you would find it in me. I was not to be feared. I was to go with Lord Henry."
#
# The young man gave one final gesture, and then sat up. " I am not going to see you in such an intolerable state of fear. I assure you I am not acting on any idea dear to me." And he flung himself down on the sofa and began to walk slowly across the room. He was trembling.
#
# The painter rose from the chair, and took up his lantern. It was still dark outside. He felt sick.
# As he had done so a cry of pain broke from his lips and he began to turn towards the door. It opened and closed again. He looked round at the empty space. He saw Lord Henry standing there, looking absolutely impassive.
# And it passed suddenly into the library, where Dorian Gray turned suddenly to Selwyn and said, " Let me in. You are not to look at the whole thing. It's just a matter of time. I am not going out into the world for the romance of an audience. I want to be loved. I want to be loved more fully than any audience I have ever known. Yes : you shall not look at the whole thing. And if you do, I will do you no wrong." There was a cry heard over the square. The bell rang, and an old gentleman came out carrying two large jars of champagne, one of which he poured over the other, and handing one to one side. He drew back the curtain, and looked at Lord Henry in the direction of the archway. After a few moments, he rose from the table to the lighted gondola, and began to turn and leave the room.
# CHAPTER IX
#
#
# THE AUSTRALIAN GRAY
# " I am going to Australia now " said Lord Henry, looking supercilious.
#
# " What do you want ? " cried the painter, who was shaking some horrible
# mild ulcers.
#
# " You want a new life. That life is not my, a new life. It is
#
#
#
#  97
#
# my native land. You have got the worst of It."
#
# " It is not Your native land, Dorian," muttered the old man.
#
# " I am not going to Australia. England has got the best of It."
#
# A knock was heard at the door, but it was too late.
#
# Through the closed door through which Dorian Gray was passing
# through the foggy night, a white hand came across Lord
# Henry. He gave it his all.
#
# " Yes, Dorian, you have the most amazing hand.
# You know quite well how to use it. It is like a charm
# that Art can use, and it is quite real. When Dorian Gray
# went to Australia in the first ship that he ever built,
# he never had any trouble with the sea. During the
# glorification that followed the return from the Spanish,
# He used not to face the waves, either, even when the
# sea was calm. Suddenly the beauty of life seemed
# to him to have gone away. Suddenly there came a knock on
# the door, and Lord Henry shuddered. He knew
# what that was. Dorian Gray had walked out of the
# room. The door was trembling, but Lord Henry
# could not help it. He drew back the curtain and looked round
# at the people in the gallery. They were all looking at him
# at once.
#
# " How serious you all are 1 I know I was a fool
# to go against myself. My mother used to talk
# all the time about how perfect you are, and
# now she is looking back on her life as an attack on
# age and woman. You have simply thrown young Dorian Gray
# into the mire."
#
# " Don't, Dorian. Take it out on the people. Look
# first at yourself. The people know You.
# The people know you. The people know how to treat
# you. Take it out on them. Don't feel so lonely,
# Dorian. Your personality is quite extraordinary."
#
# " My dear Dorian, it makes me awfully lonely.
# You should never have known I lived with you. What a pity
# I am beginning to think you must have been jealous of it all
# Life. Your own mother had no interest in marriage,
# yet you were to the world your mother's child. The
# society will laugh at you. The world will worship you.
# Life is too short a period to be of use to married people.
# I should fancy that you had become
#
# [210 | 275.69] loss=1.08 avg=2.12
# [220 | 288.00] loss=1.13 avg=2.07
# [230 | 300.29] loss=1.14 avg=2.02
# [240 | 312.62] loss=1.15 avg=1.98
# [250 | 324.91] loss=0.90 avg=1.93
# [260 | 337.23] loss=0.94 avg=1.89
# [270 | 349.53] loss=0.70 avg=1.84
# [280 | 361.83] loss=0.71 avg=1.79
# [290 | 374.12] loss=0.72 avg=1.75
# [300 | 386.39] loss=0.58 avg=1.71
# [310 | 398.68] loss=0.57 avg=1.66
# [320 | 410.98] loss=0.64 avg=1.63
# [330 | 423.28] loss=0.32 avg=1.58
# [340 | 435.57] loss=0.61 avg=1.55
# [350 | 447.87] loss=0.32 avg=1.50
# [360 | 460.18] loss=0.26 avg=1.46
# [370 | 472.46] loss=0.32 avg=1.43
# [380 | 484.75] loss=0.29 avg=1.39
# [390 | 497.06] loss=0.26 avg=1.36
# [400 | 509.34] loss=0.21 avg=1.32
# ======== SAMPLE 1 ========
#
# to have spoken to you. But to have prattled to you
# was impossible. To have
# researched you with dreadful
# reasons why I should not go on playing upon
# your stupid, petulant emotions was impossible.
#
# " I am afraid I must go now. The theatre is
# ridiculous. A play of this kind must be shown in
# a playwrights' room to the public. There,
# of course, I will not disappoint you. However,
# I must go. The ninth note
# must be played. Of course, that won't do.
# It will be most courteously said that I am in
# interest to speak to you. But, seriously, don't
# you think I am poor Harry ? "
#
# " I think you think I am."
#
# " Yes."
#
# " Ask Mr. Chapman to come with you."
#
# " I am not in a position to discuss any
# thing."
#
# " Well, Mr. Chapman ? "
#
# " Mr. Chapman. I am away."
#
# " I should like to meet you," he answered, with
# a solemn look in his eyes.
#
# Mrs. Vane seemed greatly amused.
#
# " Harry," she whispered over the intercom,
# " why don't we sit down and look at the situation
# behind the curtain ? "
#
# " Behind the curtain ? Really ? "
#
# " Behind the painting ? Yes."
#
# " Behind the painting, then. I think the
# story is simply this. During the last Parliament,
# Unicef was loath to allow girls under the age of twelve
# to go up to the Opera. This caused a
# huge outcry. The girl herself was not
# scarlet, but sat alone enthralled by the scenery.
#
#
#
#  51
#
# " Why ? " she cried. " I think it
# because, before she could go she had to see me act
# alone."
#
# " I can't explain it to you, Uncle George. I see
# that the mood of the whole place Is really revol-
# cuousness, and that only the girls can do more than
# play."
#
# " Ah ! you are mad, Harry ! but you can't
# act 1 I suppose : you shall have to see me act
# alone."
#
# " Ah ! but Aunt Agatha does it for me,"
# said Lord Henry, stepping forward, and
# looking at him.
#
# The lad did not dare to step aside. He was
# amusedly gushed over the portrait, which he
# had covered with squibs and laughed at. In
# Dorian's arms lay a booklet of white and
# black lacquer. In the corner of his blue eyes
# his mother was lighting a cigarette.
#
# " Harry," she continued, "if you entreaty me, Uncle
# George Gray must not keep it with you. It belongs
# to you alone. Let it go away. I am a doctor,
# and I know what it is. It is bad for the soul."
#
# " I must not take it away from you, Dorian.
# If it ever happens to you anywhere, get out
# Of my life. Don't let Uncle George Gray know of
# any scandal in this life. He is very popular,
# and his wife, Mary, is a very popular woman.
# I will take it away from you. You are a sort,
# 20 per cent. JK."
#
# " Ah ! that is an unbearable luxury to me,"
# remarked Lord Henry. " I think that you are
# a very charming young person, Dorian. But what is
# Harry hiding ? "
#
# " I can't believe it. There is something in
# the way; way too much of it to say. But I
# believe it when I see you. You are imbecile
# 1 You have no soul. Do you ? I say it once a
# week. Play it safe, Harry. The others will hear it
# every day. It is not of this world. Per-
# missible use of force is justifiable in
# itsentience. Play is no use. It is the ending
# of an immoral play. Play itself is immoral in
# itsentience. Play should not be taught. Let
# it be. The others will hear it and add their
# injurious opinions about it. They will become much
# younger for it."
#
# " They will, perhaps," muttered the lad,
#
# [410 | 530.50] loss=0.29 avg=1.29
# [420 | 542.83] loss=0.16 avg=1.26
# [430 | 555.16] loss=0.13 avg=1.23
# [440 | 567.46] loss=0.24 avg=1.20
# [450 | 579.77] loss=0.21 avg=1.17
# [460 | 592.07] loss=0.16 avg=1.14
# [470 | 604.37] loss=0.12 avg=1.12
# [480 | 616.70] loss=0.11 avg=1.09
# [490 | 629.03] loss=0.12 avg=1.07
# [500 | 641.33] loss=0.14 avg=1.04
# Saving checkpoint/entirebook/model-500
# [510 | 656.42] loss=0.11 avg=1.02
# [520 | 668.71] loss=0.10 avg=1.00
# [530 | 681.02] loss=0.10 avg=0.97
# [540 | 693.31] loss=0.12 avg=0.95
# [550 | 705.60] loss=0.09 avg=0.93
# [560 | 717.91] loss=0.09 avg=0.91
# [570 | 730.19] loss=0.06 avg=0.89
# [580 | 742.49] loss=0.09 avg=0.88
# [590 | 754.79] loss=0.09 avg=0.86
# [600 | 767.07] loss=0.08 avg=0.84
# ======== SAMPLE 1 ========
#  on you now. In the present case he must be dead."
#
# " What does death matter ? " cried Lord Henry. " Do you think he will
# live ? "
#
# " Every moment is a chance, Harry," he answered,
# " and every moment is a wasted opportunity. If he
# has lived, you would hardly have believed It."
#
# " My dear fellow, I am not going to believe It. It
# is horrid of you to believe it."
#
# " You will soon," said Lord Henry, going over
# the facts of the matter thoroughly. " He has not
# lived for centuries. . . . But he is certainly not dead.
# Let us not think of anything else, Harry. Life is
# nothing to him now. He has lived more than a
# century."
#
# " And who else is more likely to die than I am ? "
#
# " The public."
#
# " The clergy."
#
# The poor."
#
# " The poor."
#
# " The Church is very much in her thoughts."
#
# " The common people very nearly."
#
# " The Church is most certainly in them."
#
# " The denominations appear also."
#
# " The faithful."
#
# The people."
#
# " The prophets."
#
# " The Apostles."
#
# The Jesuits."
#
# The British civilised the race."
#
#
#
#  229
#
# Michael E. Neal was a professor of Greek at the
# Victoria."
#
# The Jesuits had a terrible influence on the art of
# painting. They made it so.
#
# Alan Campbell painted for them.
#
# But not for you."
#
# He was too wise to do that. The world is
# too wise for that."
#
# " Those who were your friends then are
# none the less."
#
# Lord Henry smiled. " The common people have
# more in them than you think," he answered. " They have
# more in them than you think. When Alan Campbell
# painted for you, everything was wonderful. The
# world is much more wonderful."
#
# He was dreadfully over-educated. There is
# some- what no artist could ever craft. The common
# people had more in them than you think."
#
# Alan Campbell belonged to the aristocracy.
# He had more in them than you think."
#
# " I don't believe that, Harry, and I don't believe
# you do either."
#
# " But do you believe in God, Mr. Gray ? "
#
# " Yes, I believe in him, Harry. The common people
# have more in them than you think."
#
# " But they are less fortunate than you think ? "
#
# Lord Henry laughed. " That is absurd. The common people
# have much more in them than you think. If the common people
# were simply more fortunate, I don't think I would believe
# anything against them. They are much more fortunate
# than we are."
#
# " But suppose, Dorian, for one moment Alan Campbell should
# be annihilated, and how would you feel ? "
#
# " I would say that in one moment we were all less fortunate
# than you are."
#
# " But imagine that, Dorian ? That is impossible."
#
# " Oh, I wish it were impossible ; but it is the only
# liability in life."
#
# " Are you, Harry, more fortunate than I am ? "
#
# " I should think so, perhaps. And yet you are hardly
# quarrelable with me than I am with you."
#
# " Even if you were to give me every-
# thing in the world in return, Alan Campbell would not
# be satisfied, Dorian, with you. These are your
# treaties, and you are to be bound up in slavery in this
# country, with all the other young men in this country who
# think that you are divine and holy. Do they not
# have your divine and holy in them ? Surely not ? "
#
#
#
# 230
#
# county censurer's gallery. I have not the slightest idea
# what you have got in store for me, Alan. I know
# that you are quite right. The misery and contempt that
# climates such a people is really given only to the bravest
# men. When they are off the beaten path they let themselves
# to themselves, and by some strange pleasure in the
# lawfully-worded phraseology follow life as it were
# " on horseback." - Now, what are you
# going
#
# [610 | 788.24] loss=0.08 avg=0.82
# [620 | 800.55] loss=0.07 avg=0.81
# [630 | 812.85] loss=0.10 avg=0.79
# [640 | 825.15] loss=0.07 avg=0.78
# [650 | 837.43] loss=0.07 avg=0.76
# [660 | 849.75] loss=0.06 avg=0.75
# [670 | 862.08] loss=0.09 avg=0.74
# [680 | 874.39] loss=0.08 avg=0.72
# [690 | 886.71] loss=0.06 avg=0.71
# [700 | 899.02] loss=0.10 avg=0.70
# [710 | 911.30] loss=0.07 avg=0.68
# [720 | 923.60] loss=0.06 avg=0.67
# [730 | 935.91] loss=0.07 avg=0.66
# [740 | 948.20] loss=0.05 avg=0.65
# [750 | 960.49] loss=0.06 avg=0.64
# [760 | 972.84] loss=0.06 avg=0.63
# [770 | 985.17] loss=0.07 avg=0.62
# [780 | 997.50] loss=0.05 avg=0.61
# [790 | 1009.77] loss=0.06 avg=0.60
# [800 | 1022.07] loss=0.05 avg=0.59
# ======== SAMPLE 1 ========
#  sort about you."
#
# She raised her hand
#
# And walked over to him, sat down, and looked
# into his eyes. He breathed a little less
#
#
#
# THE PICTURE JQ DORIAN GRAY 159
#
# while she had spoken. Then he thrust
# out his book, a harsh note of pain coming
# into its polished frame. " Yes," he continued, " I
# shall reveal the secrets of life to you. . . .
# You may believe me. I am quite certain."
#
# Then he snatched a lamp from the table, and
# stirred. " You want to bring this to me, Dorian ?
# You bring this to me, in return for all that you
# have gained."
#
# " My dear boy, I am so sorry I didn't see you.
# But I was out of sorts on the platform. Sing
# for help, and do not think about your shoes. They are
# too short."
#
# Dorian Gray looked up at him. " What a fuss
# everybody is about money now," he murmured.
#
# " Our generation has wandered in horror," said Lady
# LaForge.
#
# " If we had only the clothes we used we would
# have found them so early in life," said Lord
# Henry.
#
# " Gladys, I am not. What could they have
# told us ? They laughed at us, and insisted
# on going in with sleeveless dresses and sluggish
# half-rumped work-men. They said that they had found
# the daughter of a wealthy Greek nobleman, a man
# who was married to a certain coal-miner, and had
# emancipated the girl's mother. What was that ?
# She used to gather up bonnets and plays about oil-
# ladies, and now she remembered the sound of her
# brothers beating one another over a couch. She used
# to go down and sit down with the play-players to
# play Foucault's beautiful music. She is always
# at the Opera, and reminds me a great deal of Eloise
# Vane's, which was played at the Opera by an
# exceedingly good body. Much of what she
# did was dreadful, but there were charms in it.
# The woman was extremely charming ; the old
# Lady Agatha watched them with her sweet eyes,
# and her sweet voice. She never spoke like an
# older woman, and she was absolutely reasonable.
#
# When they reached the great grand hall a lady introduced
# them, and smiled. She was a beautiful saintly,
# with parted lips and touch. She led them
# ward into the library, and surveyed her guests.
# " Are you really so unhappy about living in
# this lodging, Dorian ? " she exclaimed. " My dear
# little girl, I want to be good. I want the most
# perfect thing in the world to be good. I want a
# perfect husband and wife. I want a stable
# that my mind can flourish in, and a career that I
# can pursue."
#
# " I can't believe it, my dear girl, but you
# absolutely believe it."
#
# " And you don't believe it, either, Dorian ? "
#
# " Oh, yes, I believe it now. I cannot believe
# it when I see you. It is a monstrous lie. An
# estimation."
#
# " Believe it ? " she exclaimed. " What nonsense it
# is ! Let it be perfectly hidden from the eyes. The
#
#
#
#  161
#
# wrinkled heroes of old saw no danger in it. They
# merely smiled at the threat. And now, seeing that
# his words were not understood, he used them.
#
# " You are really very important to me, Dorian," said
# the young lord, burying his face in his hands. " What
# I want I have all the things in the world. A wife and
# two beautiful daughters. A stable that I can believe
# us. A career that I can resume."
#
# " I want it to be your best work, I tell you,"
# spoken Lord Henry, strolling across the room.
#
# " If you want it to be yours, you must do it," said
# the young lord.
#
# " You must do it," cried his mother, pressing
# his hand. " I am sure you will do me the justice
# respect."
#
#
# " You have said everything to me in a week."
#
# " A month."
#
# "
#
# [810 | 1043.23] loss=0.07 avg=0.58
# [820 | 1055.50] loss=0.06 avg=0.57
# [830 | 1067.80] loss=0.06 avg=0.56
# [840 | 1080.09] loss=0.07 avg=0.55
# [850 | 1092.41] loss=0.07 avg=0.54
# [860 | 1104.72] loss=0.08 avg=0.53
# [870 | 1117.01] loss=0.05 avg=0.53
# [880 | 1129.32] loss=0.05 avg=0.52
# [890 | 1141.60] loss=0.07 avg=0.51
# [900 | 1153.91] loss=0.05 avg=0.50
# [910 | 1166.23] loss=0.06 avg=0.50
# [920 | 1178.53] loss=0.04 avg=0.49
# [930 | 1190.82] loss=0.06 avg=0.48
# [940 | 1203.11] loss=0.06 avg=0.47
# [950 | 1215.41] loss=0.05 avg=0.47
# [960 | 1227.74] loss=0.06 avg=0.46
# [970 | 1240.06] loss=0.04 avg=0.45
# [980 | 1252.39] loss=0.06 avg=0.45
# [990 | 1264.69] loss=0.05 avg=0.44
# [1000 | 1277.00] loss=0.04 avg=0.43
# Saving checkpoint/entirebook/model-1000
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.

# %% [markdown]
# After the model is trained, you can copy the checkpoint folder to your own Google Drive.
#
# If you want to download it to your personal computer, it's strongly recommended you copy it there first, then download from Google Drive. The checkpoint folder is copied as a `.rar` compressed file; you can download it and uncompress it locally.

# %%
gpt2.copy_checkpoint_to_gdrive(run_name='entirebook')

# %% [markdown]
# You're done! Feel free to go to the **Generate Text From The Trained Model** section to generate text based on your retrained model.

# %% [markdown]
# ## Load a Trained Model Checkpoint
#
# Running the next cell will copy the `.rar` checkpoint file from your Google Drive into the Colaboratory VM.

# %%
gpt2.copy_checkpoint_from_gdrive(run_name='entirebook')

# %% [markdown]
# The next cell will allow you to load the retrained model checkpoint + metadata necessary to generate text.
#
# **IMPORTANT NOTE:** If you want to rerun this cell, **restart the VM first** (Runtime -> Restart Runtime). You will need to rerun imports but not recopy files.

# %%
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name='entirebook')
# Out:
# Loading checkpoint checkpoint/entirebook/model-1000
# INFO:tensorflow:Restoring parameters from checkpoint/entirebook/model-1000

# %% [markdown]
# ## Generate Text From The Trained Model
#
# After you've trained the model or loaded a retrained model from checkpoint, you can now generate text. `generate` generates a single text from the loaded model.

# %%
gpt2.generate(sess, run_name='entirebook')
# Out:
# You mustn't ask me
# that, my dear Basil."
#
# " Oh, please don't, Francis," he cried, " ask me that.
# I see you have forgotten something. I must go
# back now. I insist on your coming in person.
# No gentleman comes to my rescue. Come ; let me
# go."
#
# He struck a polite note of friendly frankness. " I
# am sick of talkers who talk by means of sound Diplomacy.
# I can't understand how anyone can gain a ground of
# confession by talking to me about something as trivial As
# esprit when one has never even heard of it."
#
# " You are speaking about books," answered Dorian. " Show
# me your tickets. Don't ask me to dinner. I want you
# to make this great country great again. I want the
# soul to have all the pulses of joy that one hears in
# Verona."
#
# " Oh, yes, Harry, you are right. the country is
# worthy of its soul. The present form of luxury is
# cruelty."
#
# " I cannot understand you, Harry," said Lord Henry,
# looking at him. " You say the soul is all that one
# would ever want from a life. That is what I am
# supposed to be talking about. What is it to
# suggest that this is a very bad thing for the country ?
# I mean, what right have I to speak against a people for
# which I have no quarrel ? "
#
# " You are foolish," said Lord Henry. " It is quite true,
# from time to time, that you are a champion of wealth.
# But, God know what, I refuse to go to the club with
# you. I will refuse for ever. It is the seat of corruption in
# my mouth. I want you to come and dine with me. I
# see that there is nobody else with you. I shall
# promise to drive the place dark after 11.
# If not, I want you to come and dine alone. Do
# you understand ? "
#
# " I understand," answered Dorian, with a sigh. " But I
# can't persuade you to stay. There is something against
# me. I don't want to die. I want to be good. What do
# I want ? My soul. You don't understand me."
#
# " You don't understand me ? "
#
# " I have killed myself," said Lord Henry. " I
#  am far too reckless. Come. Let us sit down and see
# the work."
#
# The moon hung low in the early sky. The high gilt
# suns of the mills gleamed in the moonscape. The
# moon-scented plants grew monstrous and elaborate in
# the shade. The sky was pure opal, and the gypsies
# were huge and graceful. There was something in the
# grass that seemed to bring joy to one's nostrils. It
# was like a lullaby, my bud falling asleep. Of
# course I live by the leaden hope of this world. But that
# is not life. Yes, there is the death of leaden
# life in this country. The firing of people for the
# crime they commit is a death by death shooting. Every
# day is an act of murder. I have been through life,
# chang-ching for you to see through. The moment I meet
# you, I will be on the brink of a terrible and un-
# American tragedy. In one of the last moments of my life
# I will stand before the eyes of those who love me. The
# last moments of my life. I will be shown into the
# garden of horrors. The last moments of my life. I
#
#
#
#  201
#
# will spy in the branches of the grove of pine-scented
# ferns, and slay them with swift violence. I will
# be in the black. You laugh, but I die. I have a cause, you
# mad fellows, whistle but bear it. You mock, but I
# die. How have you met me ? "
#
# " I have not thought of it, Francis. I shall not
# be there. There is only room for one more. And,
# yet, I am not called a gentleman. I am not supposed to
# be in this chamber. Ah ! I was thinking of something
# more. I must see you. Do come with me. I have
# not sent my valet yet. I must call you next
# to

# %% [markdown]
# If you're creating an API based on your model and need to pass the generated text elsewhere, you can do `text = gpt2.generate(sess, return_as_list=True)[0]`
#
# You can also pass in a `prefix` to the generate function to force the text to start with a given character sequence and generate text from there (good if you add an indicator when the text starts).
#
# You can also generate multiple texts at a time by specifing `nsamples`. Unique to GPT-2, you can pass a `batch_size` to generate multiple samples in parallel, giving a massive speedup (in Colaboratory, set a maximum of 20 for `batch_size`).
#
# Other optional-but-helpful parameters for `gpt2.generate` and friends:
#
# *  **`length`**: Number of tokens to generate (default 1023, the maximum)
# * **`temperature`**: The higher the temperature, the crazier the text (default 0.7, recommended to keep between 0.7 and 1.0)
# * **`top_k`**: Limits the generated guesses to the top *k* guesses (default 0 which disables the behavior; if the generated output is super crazy, you may want to set `top_k=40`)
# * **`top_p`**: Nucleus sampling: limits the generated guesses to a cumulative probability. (gets good results on a dataset with `top_p=0.9`)
# * **`truncate`**: Truncates the input text until a given sequence, excluding that sequence (e.g. if `truncate='<|endoftext|>'`, the returned text will include everything before the first `<|endoftext|>`). It may be useful to combine this with a smaller `length` if the input texts are short.
# *  **`include_prefix`**: If using `truncate` and `include_prefix=False`, the specified `prefix` will not be included in the returned text.

# %%
gpt2.generate(sess,
              run_name = 'entirebook',
              length=1000,
              temperature=0.7,
              prefix="It is not in you Dorian to commit a murder. I am sorry if I hurt your vanity by saying so, but I assure you it is true. Crime belongs exclusively to the lower orders. I don’t blame them in the smallest degree. I should fancy that crime was to them what art is to us, simply a method of procuring extraordinary sensations.",
              nsamples=5,
              batch_size=5
              )
# Out:
# It is not in you Dorian to commit a murder. I am sorry if I hurt your vanity by saying so, but I assure you it is true. Crime belongs exclusively to the lower orders. I don’t blame them in the smallest degree. I should fancy that crime was to them what art is to us, simply a method of procuring extraordinary sensations. They
# often got intoxicated, and shot at, and slew, or wounded, or sickened us.
# The men killed in the world are much too numerous for that.
# Civilisation, as I have said times, is rather absurdly large.
# I think there are about as many people as there are in Cairo
#
# " You are a dangerous fellow. You give too much
# up to them. They say that you make them forget
# us. That is an unjust excuse for imprisoning us."
#
# " Mr. Dorian Gray Is in the Camp of G-d
# ium," cried the lad, in terror.
#
# " I have evidence against you."
#
# " No, evidence is everything."
#
# " What evidence is there ? "
#
# " Twenty men."
#
# The men stared in glee.
#
# The District Judge rose from his chair, and
# began to chew on a large piece of gum. " G-d
# ium is a rather inconvenient name," he remarked, as
# he handed it to him.
#
# " Why can't I pronounce it inconvenient ? It
# is
# not a compound word for 'of course.' "
#
# " It is a prefix for inconvenient,"
# he cutly. " It is read before the verb,
# before the noun."
#
# " How can you say inconvenient ? I want
# to take a piss."
#
#
#
# 228
#
# " I am sorry I sat for that much-appreciated phrase."
#
# " It is not its primary use
# ====================
# It is not in you Dorian to commit a murder. I am sorry if I hurt your vanity by saying so, but I assure you it is true. Crime belongs exclusively to the lower orders. I don’t blame them in the smallest degree. I should fancy that crime was to them what art is to us, simply a method of procuring extraordinary sensations. If they have been used for that reason, no art whatsoever should stand."
#
# " A method ? Do you think so ? " cried Dorian Gray ;
# " I have a theory. And it is the theory of pleasure. When I am
# painting, I have a theory. When I am playing, I have a
# play- theory. I feel that whatever I do, whether it is
# or is indifferent, it is always the same. That is
# what pleasure is. That is the reason why it is called science.
# The less chaos there is, the less variety it possesses.
# And, indeed, the less variety it possesses the less
# life is. . . . There is no mystery in any of this.
# It is simply due to the absorption of matter into
# the same bosom of which it was made. '
#
# ' You are really very comforting,' cried
# Lord Henry, at last, when the door opened for him.
# ' My dear fellow, there is something quite incredible in your
# belief. You are not even mad at this moment. You
# have simply got yourself in wrong. Don't go. Don't
# go. You have simply got yourself in wrong. Yes, I know
# you will come out strongly against me, and that is
# not very nice of you, Harry. I assure you that
# I will come out strongly. I will go out strongly."
#
# " You don't know what you are going to say, Harry, and
# I cannot help feeling that it is very disappointing. But
# it is not at all strange that he is to me the latest
# in a long line of young ladies who have committed a
# grave error."
#
# " Ah I but I can't find you," said Lord Henry, going
# across the table and throwing his hat and cane at
# them.
#
# " You don't mean to say that ? " said Dorian.
#
# " No, but I don't give a hoot about that. Young
# women are dreadful at it. They say things that
# they have come to slander me about. Well, I can
# talk to you to-night, Harry, but I cannot talk to
# you about it. What is it to be talked about ? It
# is to have elements of romance in it. Berwick's
# dress, for one. The manner in which he plays it is
# unbecoming of a club of his own. And, though
# he has all the rage of the top flight clubs of
# the world, he is even a member of the Vienna
# club of some of the finest Vienna clubs. He
#
#
#
#  127
#
# is really a gentleman, and, if he is not careful,
# the whole thing could come to nought. He tells
# me as though I were a little boy. I am not a little
# boy. I know, really, what I am. Ah, there is no
# doubt that I know more than you. The real heroine of
# Harry's novel is not even a girl. Quite the opposite.
# She is a stage actress, and, though she plays
# Julietta to me, I know that she is really only a
# few weeks younger than I am. She is prettier
# than I am, and has more of the hero's grace. I am
# somewhat disappointed in her. Everybody says that
# Julietta is better than she is, and that she is
# probably to me the most interesting actress of her generation.
# If she were of her own right, how should she rank
# her friends ? Each of them is better than the next."
#
# " Only her one best friend, Harry. That is all."
#
# " Competence, inferiority, inferiority-in-
# fact, inferiority-that-is-the-greatest-secret of all secrets.
# Who am I to judge ? "
#
# " Ah, my dear boy, the world has revealed to me,
# infinitely, the secrets of its own day."
#
# " You have been found to be foolish, mediocre,
# deluded, and, I hate to interrupt you, consider,
# present in the present moment all the actions, omissions,
# missals, failures
# ====================

# %% [markdown]
# For bulk generation, you can generate a large amount of text to a file and sort out the samples locally on your computer. The next cell will generate a generated text file with a unique timestamp.
#
# You can rerun the cells as many times as you want for even more generated texts!

# %%
gen_file = 'gpt2_gentext_{:%Y%m%d_%H%M%S}.txt'.format(datetime.utcnow())

gpt2.generate_to_file(sess,
                      destination_path=gen_file,
                      length=500,
                      temperature=0.7,
                      nsamples=100,
                      batch_size=20
                      )

# %%
# may have to run twice to get file to download
files.download(gen_file)

# %% [markdown]
# ## Generate Text From The Pretrained Model
#
# If you want to generate text from the pretrained model, not a finetuned model, pass `model_name` to `gpt2.load_gpt2()` and `gpt2.generate()`.
#
# This is currently the only way to generate text from the 774M or 1558M models with this notebook.

# %%
model_name = "774M"

gpt2.download_gpt2(model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 354Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 131Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 279Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 3.10Git [00:23, 131Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 380Mit/s]
# Fetching model.ckpt.meta: 2.10Mit [00:00, 226Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 199Mit/s]

# %%
sess = gpt2.start_tf_sess()

gpt2.load_gpt2(sess, model_name=model_name)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0828 18:37:58.571830 139905369159552 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading pretrained model models/774M/model.ckpt

# %%
gpt2.generate(sess,
              model_name=model_name,
              prefix="The secret of life is",
              length=100,
              temperature=0.7,
              top_p=0.9,
              nsamples=5,
              batch_size=5
              )
# Out:
# The secret of life is that it's really easy to make it complicated," said Bill Nye, the host of the popular science show "Bill Nye the Science Guy." "And this is one of the reasons why we all need to be smarter about science, because we can't keep up with the amazing things that are going on all the time."
#
# While Nye is correct that "everything that's going on all the time" is making the world a better place, he misses the point. This is not
# ====================
# The secret of life is in the rhythm of the universe. It's not a mystery. It's not a mystery to me. It's the nature of the universe. It's the beauty of the universe. It's the way the universe works. It's the way the universe is. It's the way the universe is going to work. It's the way the universe is. It's the way the universe is. It's the way the universe is. It's the way the universe is. It's the way
# ====================
# The secret of life is in the universe.
#
#
# -
#
# The Red Devil
#
# It's the end of the world as we know it, and the only thing that can save us is a band of super-powered individuals known as the Red Devil.
#
#
# The Red Devil is a group of super-powered individuals who are seeking the secret of life and the only way they know how to do it is by taking on the roles of a variety of different super-powered individuals, each of which has their own
# ====================
# The secret of life is in the mixing of the elements, and it is the mixing of the elements that makes life possible."
#
# But in the world of food science, the idea of a "complex" or "complexity" is almost entirely imaginary.
#
# As a scientist, I'm fascinated by the question of how life first began.
#
# It's the question that drives my work and the work of the scientists who work on it.
#
# My current research is exploring how microbes work in the first moments
# ====================
# The secret of life is the journey of life, the search for the truth.
#
# 4.4.2. The last thing you know
#
# There is nothing more important than the last thing you know.
#
# 4.4.3. The little things that make all the difference
#
# The little things that make all the difference.
#
# 4.4.4. The truth is the best teacher
#
# The truth is the best teacher.
#
# 4.4.5. The truth is what
# ====================

# %% [markdown]
# # Etcetera
#
# If the notebook has errors (e.g. GPU Sync Fail), force-kill the Colaboratory virtual machine and restart it with the command below:

# %%
# !kill -9 -1
